# %%
IS_GPU = True
IS_COLAB = True
if IS_COLAB:
  from google.colab import drive
  drive.mount('/content/drive')
  
  cur_path = "/content/drive/MyDrive/ML/RAIFDS/train.csv"
  # !cp $cur_path .
  cur_path = "/content/drive/MyDrive/ML/RAIFDS/test.csv"
  # !cp $cur_path .
  cur_path = "/content/drive/MyDrive/ML/RAIFDS/test_submission.csv"
  # !cp $cur_path .
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Импорт нужных библиотек
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
import tensorflow.keras as keras
from sklearn.preprocessing import MinMaxScaler, QuantileTransformer
from sklearn.model_selection import KFold
import lightgbm as lgb
import xgboost as xgb
import time
from scipy.optimize import minimize

def reset_tensorflow_session():
    tf.keras.backend.clear_session()
    tf.random.set_seed(41)
    np.random.seed(41)

# %%
THRESHOLD = 0.15
NEGATIVE_WEIGHT = 1.1

def deviation_metric_one_sample(y_true, y_pred):
    """
    Реализация кастомной метрики для хакатона.
    :param y_true: float, реальная цена
    :param y_pred: float, предсказанная цена
    :return: float, значение метрики
    """
    deviation = (y_pred - y_true) / np.maximum(1e-8, y_true)
    if np.abs(deviation) <= THRESHOLD:
        return 0
    elif deviation <= - 4 * THRESHOLD:
        return 9 * NEGATIVE_WEIGHT
    elif deviation < -THRESHOLD:
        return NEGATIVE_WEIGHT * ((deviation / THRESHOLD) + 1) ** 2
    elif deviation < 4 * THRESHOLD:
        return ((deviation / THRESHOLD) - 1) ** 2
    else:
        return 9
def deviation_metric(y_true, y_pred):
    return np.array([deviation_metric_one_sample(y_true[n], y_pred[n]) for n in range(len(y_true))]).mean()

# %%
#Категориальные данные
CATEGORICAL_FEATURES_COLUMNS = ['region', 'city', 'realty_type', 'floor']
#Численные данные
NUM_FEATURES_COLUMNS = ['lat', 'lng', 'osm_amenity_points_in_0.001',
       'osm_amenity_points_in_0.005', 'osm_amenity_points_in_0.0075',
       'osm_amenity_points_in_0.01', 'osm_building_points_in_0.001',
       'osm_building_points_in_0.005', 'osm_building_points_in_0.0075',
       'osm_building_points_in_0.01', 'osm_catering_points_in_0.001',
       'osm_catering_points_in_0.005', 'osm_catering_points_in_0.0075',
       'osm_catering_points_in_0.01', 'osm_city_closest_dist',
      'osm_city_nearest_population',
       'osm_crossing_closest_dist', 'osm_crossing_points_in_0.001',
       'osm_crossing_points_in_0.005', 'osm_crossing_points_in_0.0075',
       'osm_crossing_points_in_0.01', 'osm_culture_points_in_0.001',
       'osm_culture_points_in_0.005', 'osm_culture_points_in_0.0075',
       'osm_culture_points_in_0.01', 'osm_finance_points_in_0.001',
       'osm_finance_points_in_0.005', 'osm_finance_points_in_0.0075',
       'osm_finance_points_in_0.01', 'osm_healthcare_points_in_0.005',
       'osm_healthcare_points_in_0.0075', 'osm_healthcare_points_in_0.01',
       'osm_historic_points_in_0.005', 'osm_historic_points_in_0.0075',
       'osm_historic_points_in_0.01', 'osm_hotels_points_in_0.005',
       'osm_hotels_points_in_0.0075', 'osm_hotels_points_in_0.01',
       'osm_leisure_points_in_0.005', 'osm_leisure_points_in_0.0075',
       'osm_leisure_points_in_0.01', 'osm_offices_points_in_0.001',
       'osm_offices_points_in_0.005', 'osm_offices_points_in_0.0075',
       'osm_offices_points_in_0.01', 'osm_shops_points_in_0.001',
       'osm_shops_points_in_0.005', 'osm_shops_points_in_0.0075',
       'osm_shops_points_in_0.01', 'osm_subway_closest_dist',
       'osm_train_stop_closest_dist', 'osm_train_stop_points_in_0.005',
       'osm_train_stop_points_in_0.0075', 'osm_train_stop_points_in_0.01',
       'osm_transport_stop_closest_dist', 'osm_transport_stop_points_in_0.005',
       'osm_transport_stop_points_in_0.0075',
       'osm_transport_stop_points_in_0.01',
       'reform_count_of_houses_1000', 'reform_count_of_houses_500',
       'reform_house_population_1000', 'reform_house_population_500',
       'reform_mean_floor_count_1000', 'reform_mean_floor_count_500',
       'reform_mean_year_building_1000', 'reform_mean_year_building_500','total_square']
#Таргет
TARGET_COLUMNS = ['per_square_meter_price']

# %%
#Считываем данные
def read_train_test():
  train = pd.read_csv('train.csv')
  test = pd.read_csv('test.csv')
  test_submission = pd.read_csv('test_submission.csv')
  return train, test

#Encoder категориальных фичей
def encode_categorical_features(df, categorical_columns):
  for column in categorical_columns:    
    dict_encoding = {key : val for val, key in enumerate(df[column].unique())}
    df[column] = df[column].map(dict_encoding)
  return df

#Квантильное преобразование данных
def get_quantile_transform(_df, columns_for_quantilization, random_state = 41, n_quantiles = 100, output_distribution = 'normal'):
  df = _df.copy()
  for col in columns_for_quantilization:    
    qt = QuantileTransformer(random_state = random_state, n_quantiles = n_quantiles, output_distribution = output_distribution)
    df[col] = qt.fit_transform(df[[col]])
  return df

#МинМакс преобразование данных
def get_minmax_transform(_df, columns_for_quantilization, min_value = -1, max_value = 1):
  df = _df.copy()
  for col in columns_for_quantilization:    
    scaler = MinMaxScaler(feature_range=(min_value, max_value))
    df[col] = scaler.fit_transform(df[[col]])
  return df    
  
#Подготавливаем данные для модельки
def preprocess_data(train, test):
  train = train[train.price_type == 1].reset_index(drop=True)
  train['is_train'] = 1
  test['is_train'] = 0
  data = pd.concat([train, test]).reset_index(drop=True)
  #Hotencoding для категориальных фичей
  data = encode_categorical_features(data, CATEGORICAL_FEATURES_COLUMNS)  
  #Нормализация численных данных
  data = get_quantile_transform(data, NUM_FEATURES_COLUMNS)
  data = get_minmax_transform(data, NUM_FEATURES_COLUMNS)
  #Заполняем NaN значения
  data = data.fillna(data.mean())
  train = data[data.is_train == 1].reset_index(drop=True)
  test = data[data.is_train == 0].reset_index(drop=True)
  train = train.drop(columns = ['is_train'])
  test = test.drop(columns = ['is_train'])
  return train, test

# %%
#Стандартное разбиение данных на 5 фолдов случайным образом
def get_standart_split(data, n_splits = 5, seed = 41):
  kf = KFold(n_splits = n_splits, random_state = seed, shuffle = True)
  split_list = []
  for train_index, test_index in kf.split(data):
    split_list += [(train_index, test_index)]
  return split_list

# %%
#Создаем tf.Dataset по массивам данных
def get_dataset(arr_features, arr_target, arr_region, arr_city, arr_realty, batch_size):
    return tf.data.Dataset.from_tensor_slices(
        (
            {
                "model_features_input" : arr_features,
             "model_region_input" : arr_region,
             "model_city_input" : arr_city,
             "model_realty_input" : arr_realty,             
            },
            {
                "model_output" : arr_target,             
            },
        )
    ).batch(batch_size)

#Фиксируем поряд фичей в dataframe
def get_columns_order(columns):
  columns_order = sorted([x for x in columns if not x in (CATEGORICAL_FEATURES_COLUMNS + TARGET_COLUMNS)])
  return columns_order + CATEGORICAL_FEATURES_COLUMNS + TARGET_COLUMNS

# %%
#Коллбэк, для отслеживания целевой метрики
class CustomCallback(keras.callbacks.Callback):    
    def __init__(self, val_dataset, val_targets):      
        super(CustomCallback, self).__init__()
        self.val_targets = val_targets
        self.val_dataset = val_dataset        

    def on_epoch_end(self, epoch, logs=None):
        predicts = self.model.predict(self.val_dataset)[:,0]
        targets = self.val_targets[:,0]
        print(f"Текущий реальный скор(валидационная часть): {np.round(deviation_metric(targets, predicts), 4)}")

def Dropout(x):
  return keras.layers.Dropout(x)

def Flatten():
    return keras.layers.Flatten()

def Concatenate():
    return keras.layers.Concatenate()

#Функция обучения модели
def fit(model, epochs, train_dataset, val_dataset, val_targets, verbose = True):        
  if IS_GPU:
    print(f"Начинаю обучение модели (GPU) количество эпох = {epochs}")
    with tf.device('/device:GPU:0'):
      #Коллбэк для остановки, если модель перестала обучаться          
      early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta = 2.5e-6, patience = 100, restore_best_weights = True, mode = 'min')
      #Коллбэк для уменьшения скорости обучения
      lr_callback = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor = 0.5, patience = 10, min_lr = 1e-9, mode = 'min')
      #Кастомный коллбэк для отображения скора по целевой метрике
      metric_callback = CustomCallback(val_dataset, val_targets)
      history = model.fit(train_dataset, epochs = epochs, validation_data = val_dataset, verbose = verbose, shuffle=True, callbacks=[early_stopping_callback, lr_callback, metric_callback], workers = -1)
      return history
  else:        
      print(f"Начинаю обучение модели (СPU) количество эпох = {epochs}")        
      #Коллбэк для остановки, если модель перестала обучаться          
      early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta = 2.5e-6, patience = 100, restore_best_weights = True, mode = 'min')
      #Коллбэк для уменьшения скорости обучения
      lr_callback = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor = 0.5, patience = 10, min_lr = 1e-9, mode = 'min')
      #Кастомный коллбэк для отображения скора по целевой метрике
      metric_callback = CustomCallback(val_dataset, val_targets)
      history = model.fit(train_dataset, epochs = epochs, validation_data = val_dataset, verbose = verbose, shuffle=True, callbacks=[early_stopping_callback, lr_callback, metric_callback], workers = -1)
      return history

#Реализация кастомной функции потерь для обучения
def tf_custom_loss(y_true, y_pred):     
    threshold = 0.6     
    error = tf.abs(y_true - y_pred) / y_true
    is_small_error = error <= threshold     
    small_error_loss = tf.square(error / 0.15 - 1)    
    big_error_loss = 9.0 * tf.ones_like(small_error_loss) + tf.abs(error)
    #big_error_loss = (3.0 * tf.ones_like(small_error_loss) + tf.abs(error)) ** 2
    return tf.where(is_small_error, small_error_loss, big_error_loss)

#Компиляция текущей модели
def compile_model(train_dataset, val_dataset, num_features, max_realty, max_region, max_city, lr = 5e-4):  
  reset_tensorflow_session()       
  optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
          
  model_input_layer = tf.keras.Input(shape = (num_features), name = "model_features_input")
  model_input_realty = tf.keras.Input(shape = (1), name = "model_realty_input")
  model_input_region = tf.keras.Input(shape = (1), name = "model_region_input")
  model_input_city = tf.keras.Input(shape = (1), name = "model_city_input")

  model_embedding_layer_realty = keras.layers.Embedding(max_realty + 1, 4, input_length=1, dtype=tf.float64)(model_input_realty)
  model_embedding_layer_region = keras.layers.Embedding(max_region + 1, 32, input_length=1, dtype=tf.float64)(model_input_region)
  model_embedding_layer_city = keras.layers.Embedding(max_city + 1, 32, input_length=1, dtype=tf.float64)(model_input_city)

  concatenated_input_layer = Concatenate()([Flatten()(model_embedding_layer_realty), Flatten()(model_embedding_layer_region), Flatten()(model_embedding_layer_city), Flatten()(model_input_layer)])

  layer_0 = keras.layers.Dense(128, activation="relu")(concatenated_input_layer)  
  layer_1 = keras.layers.Dense(64, activation="relu")(layer_0)  
  layer_2 = keras.layers.Dense(32, activation="relu")(layer_1)
  model_output_layer = keras.layers.Dense(1, activation="relu", name = "model_output")(layer_2)
          
  cur_model = keras.Model(
      inputs = [
          model_input_layer,
          model_input_realty,          
          model_input_region,
          model_input_city,
      ], 
      outputs = [
          model_output_layer,            
      ])                                
  
  print(f"Модель: input_shape = {cur_model.input_shape} output_shape = {cur_model.output_shape}")
  cur_model.compile(loss = tf_custom_loss, optimizer = optimizer)#, run_eagerly=True)
  #cur_model.compile(loss = my_huber_loss, optimizer = optimizer)#, run_eagerly=True)
  #cur_model.compile(loss = tf.keras.losses.MeanAbsoluteError(), optimizer = optimizer)#, run_eagerly=True)
  #  
  return cur_model

# %%
#Считываем данные и подготавливаем их
train, test = read_train_test()
train, test = preprocess_data(train, test)
features_columns_order = get_columns_order(train.columns.values.tolist())
split_list = get_standart_split(train)

# %%
start_train_model_time = time.time()
#Размер батча для Dataset
BATCH_SIZE = int(2 ** 5)
#Количество эпох обучения
EPOCHS = 500
#Количество численных входных переменных модели
NUM_FEATURES = len(NUM_FEATURES_COLUMNS)
#Макс. значения категориалных фичей
MAX_REALTY = max(train['realty_type'].max(), test['realty_type'].max())
MAX_REGION = max(train['region'].max(), test['region'].max())
MAX_CITY = max(train['city'].max(), test['city'].max())
#Коэффициент домножения таргета, с целью быстрейшего сходимости модельки и лучшего обучения
MUL_TARGET = 5e-5

scores = []
nn_predicts = np.zeros(len(train))
models_nn = []

for fold_num, (train_indexes, valid_indexes) in enumerate(split_list):  
  start_time = time.time()
  print(f"Фолд: {fold_num}")

  train_sub_df = train[features_columns_order].loc[train_indexes].reset_index(drop=True)    
  valid_sub_df = train[features_columns_order].loc[valid_indexes].reset_index(drop=True)    

  print(f"Размер трейна = {train_sub_df.shape} Размер валидации = {valid_sub_df.shape}")
  
  #Строим датасеты
  train_ds = get_dataset(
      train_sub_df[NUM_FEATURES_COLUMNS].values, 
      train_sub_df[TARGET_COLUMNS].values * MUL_TARGET, 
      train_sub_df[['region']].values, 
      train_sub_df[['city']].values, 
      train_sub_df[['realty_type']].values, 
      BATCH_SIZE)
  valid_ds = get_dataset(
      valid_sub_df[NUM_FEATURES_COLUMNS].values, 
      valid_sub_df[TARGET_COLUMNS].values * MUL_TARGET, 
      valid_sub_df[['region']].values, 
      valid_sub_df[['city']].values, 
      valid_sub_df[['realty_type']].values, 
      len(valid_sub_df))

  #Компилируем модель
  model = compile_model(train_ds, valid_ds, NUM_FEATURES, MAX_REALTY, MAX_REGION, MAX_CITY)  
  #Обучаем модель
  fit(model, EPOCHS, train_ds, valid_ds, valid_sub_df[TARGET_COLUMNS].values * MUL_TARGET)

  predict_on_validation = model.predict(valid_ds)[:,0] / MUL_TARGET
  nn_predicts[valid_indexes] = predict_on_validation
  targets_for_validation = valid_sub_df[TARGET_COLUMNS].values[:,0]
  current_score = deviation_metric(targets_for_validation, predict_on_validation)
  scores += [current_score]
  models_nn  += [model]
  print(f"Скор для фолда({fold_num}) : {np.round(current_score, 4)} средний скор на префиксе = {np.round(np.mean(scores), 4)} это заняло = {int(time.time() - start_time)} сек.")
print(f"Процесс обучения модели занял = {int(time.time() - start_train_model_time)} секунд")
# Out:
# Фолд: 0
# Размер трейна = (3594, 77) Размер валидации = (899, 77)
# Модель: input_shape = [(None, 67), (None, 1), (None, 1), (None, 1)] output_shape = (None, 1)
# Начинаю обучение модели (GPU) количество эпох = 500
# Epoch 1/500
# 113/113 [==============================] - 2s 5ms/step - loss: 4.1179 - val_loss: 2.2921
# Текущий реальный скор(валидационная часть): 2.2322
# Epoch 2/500
# 113/113 [==============================] - 0s 4ms/step - loss: 2.0720 - val_loss: 1.8735
# Текущий реальный скор(валидационная часть): 1.7986
# Epoch 3/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.7587 - val_loss: 1.7982
# Текущий реальный скор(валидационная часть): 1.7021
# Epoch 4/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.6115 - val_loss: 1.7801
# Текущий реальный скор(валидационная часть): 1.6824
# Epoch 5/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.5109 - val_loss: 1.7363
# Текущий реальный скор(валидационная часть): 1.6374
# Epoch 6/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.4357 - val_loss: 1.6836
# Текущий реальный скор(валидационная часть): 1.5938
# Epoch 7/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.3775 - val_loss: 1.6526
# Текущий реальный скор(валидационная часть): 1.5666
# Epoch 8/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.3250 - val_loss: 1.6470
# Текущий реальный скор(валидационная часть): 1.5531
# Epoch 9/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.2725 - val_loss: 1.6262
# Текущий реальный скор(валидационная часть): 1.5378
# Epoch 10/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.2212 - val_loss: 1.6228
# Текущий реальный скор(валидационная часть): 1.5349
# Epoch 11/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.1793 - val_loss: 1.5943
# Текущий реальный скор(валидационная часть): 1.5129
# Epoch 12/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.1218 - val_loss: 1.5932
# Текущий реальный скор(валидационная часть): 1.5086
# Epoch 13/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.0767 - val_loss: 1.5857
# Текущий реальный скор(валидационная часть): 1.4931
# Epoch 14/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.0451 - val_loss: 1.5796
# Текущий реальный скор(валидационная часть): 1.4835
# Epoch 15/500
# 113/113 [==============================] - 1s 5ms/step - loss: 1.0230 - val_loss: 1.5698
# Текущий реальный скор(валидационная часть): 1.4827
# Epoch 16/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.0310 - val_loss: 1.6086
# Текущий реальный скор(валидационная часть): 1.5147
# Epoch 17/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.9914 - val_loss: 1.5875
# Текущий реальный скор(валидационная часть): 1.4665
# Epoch 18/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.9898 - val_loss: 1.5780
# Текущий реальный скор(валидационная часть): 1.4608
# Epoch 19/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.9568 - val_loss: 1.5505
# Текущий реальный скор(валидационная часть): 1.4487
# Epoch 20/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.9599 - val_loss: 1.5176
# Текущий реальный скор(валидационная часть): 1.4221
# Epoch 21/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.9726 - val_loss: 1.5277
# Текущий реальный скор(валидационная часть): 1.4651
# Epoch 22/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.9337 - val_loss: 1.5769
# Текущий реальный скор(валидационная часть): 1.5296
# Epoch 23/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.9552 - val_loss: 1.8302
# Текущий реальный скор(валидационная часть): 1.6962
# Epoch 24/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.0909 - val_loss: 1.6583
# Текущий реальный скор(валидационная часть): 1.5125
# Epoch 25/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.8930 - val_loss: 1.6062
# Текущий реальный скор(валидационная часть): 1.4762
# Epoch 26/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.8224 - val_loss: 1.5767
# Текущий реальный скор(валидационная часть): 1.453
# Epoch 27/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.7826 - val_loss: 1.5858
# Текущий реальный скор(валидационная часть): 1.4526
# Epoch 28/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.7535 - val_loss: 1.6841
# Текущий реальный скор(валидационная часть): 1.5305
# Epoch 29/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.7395 - val_loss: 1.6784
# Текущий реальный скор(валидационная часть): 1.5266
# Epoch 30/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.7324 - val_loss: 1.6714
# Текущий реальный скор(валидационная часть): 1.5179
# Epoch 31/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.7988 - val_loss: 1.5929
# Текущий реальный скор(валидационная часть): 1.4408
# Epoch 32/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.7181 - val_loss: 1.5494
# Текущий реальный скор(валидационная часть): 1.4044
# Epoch 33/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.6742 - val_loss: 1.5471
# Текущий реальный скор(валидационная часть): 1.4004
# Epoch 34/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.6450 - val_loss: 1.5391
# Текущий реальный скор(валидационная часть): 1.3939
# Epoch 35/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.6267 - val_loss: 1.5331
# Текущий реальный скор(валидационная часть): 1.3903
# Epoch 36/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.6119 - val_loss: 1.5197
# Текущий реальный скор(валидационная часть): 1.3823
# Epoch 37/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5991 - val_loss: 1.5158
# Текущий реальный скор(валидационная часть): 1.3804
# Epoch 38/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5882 - val_loss: 1.5164
# Текущий реальный скор(валидационная часть): 1.3792
# Epoch 39/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5787 - val_loss: 1.5188
# Текущий реальный скор(валидационная часть): 1.3822
# Epoch 40/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5693 - val_loss: 1.5260
# Текущий реальный скор(валидационная часть): 1.3885
# Epoch 41/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5608 - val_loss: 1.5323
# Текущий реальный скор(валидационная часть): 1.393
# Epoch 42/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5532 - val_loss: 1.5364
# Текущий реальный скор(валидационная часть): 1.3952
# Epoch 43/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5462 - val_loss: 1.5440
# Текущий реальный скор(валидационная часть): 1.4023
# Epoch 44/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5395 - val_loss: 1.5474
# Текущий реальный скор(валидационная часть): 1.4056
# Epoch 45/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5333 - val_loss: 1.5498
# Текущий реальный скор(валидационная часть): 1.4064
# Epoch 46/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5277 - val_loss: 1.5521
# Текущий реальный скор(валидационная часть): 1.4084
# Epoch 47/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5227 - val_loss: 1.5410
# Текущий реальный скор(валидационная часть): 1.4032
# Epoch 48/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5387 - val_loss: 1.5449
# Текущий реальный скор(валидационная часть): 1.407
# Epoch 49/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5336 - val_loss: 1.5643
# Текущий реальный скор(валидационная часть): 1.4197
# Epoch 50/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5362 - val_loss: 1.5926
# Текущий реальный скор(валидационная часть): 1.4399
# Epoch 51/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.5320 - val_loss: 1.6155
# Текущий реальный скор(валидационная часть): 1.456
# Epoch 52/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5259 - val_loss: 1.6191
# Текущий реальный скор(валидационная часть): 1.4606
# Epoch 53/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5241 - val_loss: 1.6181
# Текущий реальный скор(валидационная часть): 1.4621
# Epoch 54/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5194 - val_loss: 1.6149
# Текущий реальный скор(валидационная часть): 1.4555
# Epoch 55/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5249 - val_loss: 1.6012
# Текущий реальный скор(валидационная часть): 1.4503
# Epoch 56/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.5236 - val_loss: 1.5840
# Текущий реальный скор(валидационная часть): 1.4393
# Epoch 57/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5252 - val_loss: 1.5706
# Текущий реальный скор(валидационная часть): 1.4297
# Epoch 58/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5678 - val_loss: 1.4436
# Текущий реальный скор(валидационная часть): 1.3554
# Epoch 59/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5665 - val_loss: 1.4393
# Текущий реальный скор(валидационная часть): 1.347
# Epoch 60/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5525 - val_loss: 1.4401
# Текущий реальный скор(валидационная часть): 1.3455
# Epoch 61/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5407 - val_loss: 1.4450
# Текущий реальный скор(валидационная часть): 1.3447
# Epoch 62/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5307 - val_loss: 1.4515
# Текущий реальный скор(валидационная часть): 1.3479
# Epoch 63/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5226 - val_loss: 1.4561
# Текущий реальный скор(валидационная часть): 1.3491
# Epoch 64/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5159 - val_loss: 1.4639
# Текущий реальный скор(валидационная часть): 1.3505
# Epoch 65/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5092 - val_loss: 1.4680
# Текущий реальный скор(валидационная часть): 1.3522
# Epoch 66/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5039 - val_loss: 1.4718
# Текущий реальный скор(валидационная часть): 1.3542
# Epoch 67/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4969 - val_loss: 1.4752
# Текущий реальный скор(валидационная часть): 1.3682
# Epoch 68/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5029 - val_loss: 1.4828
# Текущий реальный скор(валидационная часть): 1.3628
# Epoch 69/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4931 - val_loss: 1.4843
# Текущий реальный скор(валидационная часть): 1.3631
# Epoch 70/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4926 - val_loss: 1.5301
# Текущий реальный скор(валидационная часть): 1.3905
# Epoch 71/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4852 - val_loss: 1.5259
# Текущий реальный скор(валидационная часть): 1.3873
# Epoch 72/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4818 - val_loss: 1.5225
# Текущий реальный скор(валидационная часть): 1.3849
# Epoch 73/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4792 - val_loss: 1.5208
# Текущий реальный скор(валидационная часть): 1.3837
# Epoch 74/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4769 - val_loss: 1.5193
# Текущий реальный скор(валидационная часть): 1.383
# Epoch 75/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4749 - val_loss: 1.5185
# Текущий реальный скор(валидационная часть): 1.3825
# Epoch 76/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4731 - val_loss: 1.5176
# Текущий реальный скор(валидационная часть): 1.3817
# Epoch 77/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4714 - val_loss: 1.5172
# Текущий реальный скор(валидационная часть): 1.3815
# Epoch 78/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4698 - val_loss: 1.5171
# Текущий реальный скор(валидационная часть): 1.3815
# Epoch 79/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4682 - val_loss: 1.5170
# Текущий реальный скор(валидационная часть): 1.3815
# Epoch 80/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4709 - val_loss: 1.4878
# Текущий реальный скор(валидационная часть): 1.3637
# Epoch 81/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4694 - val_loss: 1.4870
# Текущий реальный скор(валидационная часть): 1.3632
# Epoch 82/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4681 - val_loss: 1.4866
# Текущий реальный скор(валидационная часть): 1.363
# Epoch 83/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4669 - val_loss: 1.4866
# Текущий реальный скор(валидационная часть): 1.363
# Epoch 84/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4659 - val_loss: 1.4866
# Текущий реальный скор(валидационная часть): 1.363
# Epoch 85/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4648 - val_loss: 1.4870
# Текущий реальный скор(валидационная часть): 1.3633
# Epoch 86/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4639 - val_loss: 1.4858
# Текущий реальный скор(валидационная часть): 1.363
# Epoch 87/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4631 - val_loss: 1.4861
# Текущий реальный скор(валидационная часть): 1.3632
# Epoch 88/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.4622 - val_loss: 1.4862
# Текущий реальный скор(валидационная часть): 1.3633
# Epoch 89/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4614 - val_loss: 1.4862
# Текущий реальный скор(валидационная часть): 1.3633
# Epoch 90/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4645 - val_loss: 1.4766
# Текущий реальный скор(валидационная часть): 1.3595
# Epoch 91/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4655 - val_loss: 1.4774
# Текущий реальный скор(валидационная часть): 1.3599
# Epoch 92/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4648 - val_loss: 1.4780
# Текущий реальный скор(валидационная часть): 1.3602
# Epoch 93/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4641 - val_loss: 1.4785
# Текущий реальный скор(валидационная часть): 1.3604
# Epoch 94/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4635 - val_loss: 1.4797
# Текущий реальный скор(валидационная часть): 1.3606
# Epoch 95/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4629 - val_loss: 1.4798
# Текущий реальный скор(валидационная часть): 1.3607
# Epoch 96/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4624 - val_loss: 1.4804
# Текущий реальный скор(валидационная часть): 1.3609
# Epoch 97/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4618 - val_loss: 1.4807
# Текущий реальный скор(валидационная часть): 1.3612
# Epoch 98/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4613 - val_loss: 1.4810
# Текущий реальный скор(валидационная часть): 1.3613
# Epoch 99/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4608 - val_loss: 1.4813
# Текущий реальный скор(валидационная часть): 1.3615
# Epoch 100/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4633 - val_loss: 1.4955
# Текущий реальный скор(валидационная часть): 1.3672
# Epoch 101/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4606 - val_loss: 1.4959
# Текущий реальный скор(валидационная часть): 1.3675
# Epoch 102/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4602 - val_loss: 1.4962
# Текущий реальный скор(валидационная часть): 1.3677
# Epoch 103/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4598 - val_loss: 1.4965
# Текущий реальный скор(валидационная часть): 1.3679
# Epoch 104/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4595 - val_loss: 1.4967
# Текущий реальный скор(валидационная часть): 1.3681
# Epoch 105/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4592 - val_loss: 1.4970
# Текущий реальный скор(валидационная часть): 1.3683
# Epoch 106/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4589 - val_loss: 1.4972
# Текущий реальный скор(валидационная часть): 1.3684
# Epoch 107/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4586 - val_loss: 1.4973
# Текущий реальный скор(валидационная часть): 1.3686
# Epoch 108/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4583 - val_loss: 1.4975
# Текущий реальный скор(валидационная часть): 1.3687
# Epoch 109/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4580 - val_loss: 1.4977
# Текущий реальный скор(валидационная часть): 1.3688
# Epoch 110/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4580 - val_loss: 1.5054
# Текущий реальный скор(валидационная часть): 1.3729
# Epoch 111/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4566 - val_loss: 1.5065
# Текущий реальный скор(валидационная часть): 1.3737
# Epoch 112/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4563 - val_loss: 1.5068
# Текущий реальный скор(валидационная часть): 1.3738
# Epoch 113/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4561 - val_loss: 1.5068
# Текущий реальный скор(валидационная часть): 1.3739
# Epoch 114/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4560 - val_loss: 1.5068
# Текущий реальный скор(валидационная часть): 1.3739
# Epoch 115/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4559 - val_loss: 1.5069
# Текущий реальный скор(валидационная часть): 1.374
# Epoch 116/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4557 - val_loss: 1.5069
# Текущий реальный скор(валидационная часть): 1.374
# Epoch 117/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4556 - val_loss: 1.5069
# Текущий реальный скор(валидационная часть): 1.374
# Epoch 118/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4555 - val_loss: 1.5070
# Текущий реальный скор(валидационная часть): 1.3741
# Epoch 119/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4553 - val_loss: 1.5070
# Текущий реальный скор(валидационная часть): 1.3741
# Epoch 120/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4548 - val_loss: 1.5094
# Текущий реальный скор(валидационная часть): 1.3756
# Epoch 121/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4545 - val_loss: 1.5111
# Текущий реальный скор(валидационная часть): 1.3763
# Epoch 122/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.4543 - val_loss: 1.5115
# Текущий реальный скор(валидационная часть): 1.3765
# Epoch 123/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4542 - val_loss: 1.5117
# Текущий реальный скор(валидационная часть): 1.3766
# Epoch 124/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4541 - val_loss: 1.5118
# Текущий реальный скор(валидационная часть): 1.3767
# Epoch 125/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4541 - val_loss: 1.5118
# Текущий реальный скор(валидационная часть): 1.3767
# Epoch 126/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4540 - val_loss: 1.5118
# Текущий реальный скор(валидационная часть): 1.3768
# Epoch 127/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4539 - val_loss: 1.5119
# Текущий реальный скор(валидационная часть): 1.3768
# Epoch 128/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4539 - val_loss: 1.5119
# Текущий реальный скор(валидационная часть): 1.3768
# Epoch 129/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4538 - val_loss: 1.5119
# Текущий реальный скор(валидационная часть): 1.3768
# Epoch 130/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4534 - val_loss: 1.5126
# Текущий реальный скор(валидационная часть): 1.3772
# Epoch 131/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4533 - val_loss: 1.5130
# Текущий реальный скор(валидационная часть): 1.3775
# Epoch 132/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4533 - val_loss: 1.5133
# Текущий реальный скор(валидационная часть): 1.3777
# Epoch 133/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4532 - val_loss: 1.5135
# Текущий реальный скор(валидационная часть): 1.3778
# Epoch 134/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4532 - val_loss: 1.5136
# Текущий реальный скор(валидационная часть): 1.3779
# Epoch 135/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4531 - val_loss: 1.5137
# Текущий реальный скор(валидационная часть): 1.378
# Epoch 136/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4531 - val_loss: 1.5137
# Текущий реальный скор(валидационная часть): 1.378
# Epoch 137/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4531 - val_loss: 1.5138
# Текущий реальный скор(валидационная часть): 1.3781
# Epoch 138/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4530 - val_loss: 1.5138
# Текущий реальный скор(валидационная часть): 1.3781
# Epoch 139/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4530 - val_loss: 1.5138
# Текущий реальный скор(валидационная часть): 1.3781
# Epoch 140/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4528 - val_loss: 1.5140
# Текущий реальный скор(валидационная часть): 1.3782
# Epoch 141/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4527 - val_loss: 1.5142
# Текущий реальный скор(валидационная часть): 1.3783
# Epoch 142/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4527 - val_loss: 1.5143
# Текущий реальный скор(валидационная часть): 1.3784
# Epoch 143/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4527 - val_loss: 1.5144
# Текущий реальный скор(валидационная часть): 1.3785
# Epoch 144/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4527 - val_loss: 1.5145
# Текущий реальный скор(валидационная часть): 1.3785
# Epoch 145/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.4527 - val_loss: 1.5145
# Текущий реальный скор(валидационная часть): 1.3786
# Epoch 146/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4526 - val_loss: 1.5146
# Текущий реальный скор(валидационная часть): 1.3786
# Epoch 147/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4526 - val_loss: 1.5146
# Текущий реальный скор(валидационная часть): 1.3786
# Epoch 148/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4526 - val_loss: 1.5147
# Текущий реальный скор(валидационная часть): 1.3787
# Epoch 149/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4526 - val_loss: 1.5147
# Текущий реальный скор(валидационная часть): 1.3787
# Epoch 150/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4525 - val_loss: 1.5148
# Текущий реальный скор(валидационная часть): 1.3787
# Epoch 151/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4525 - val_loss: 1.5148
# Текущий реальный скор(валидационная часть): 1.3788
# Epoch 152/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4525 - val_loss: 1.5149
# Текущий реальный скор(валидационная часть): 1.3788
# Epoch 153/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4524 - val_loss: 1.5149
# Текущий реальный скор(валидационная часть): 1.3788
# Epoch 154/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4524 - val_loss: 1.5149
# Текущий реальный скор(валидационная часть): 1.3789
# Epoch 155/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4524 - val_loss: 1.5150
# Текущий реальный скор(валидационная часть): 1.3789
# Epoch 156/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4524 - val_loss: 1.5150
# Текущий реальный скор(валидационная часть): 1.3789
# Epoch 157/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4524 - val_loss: 1.5150
# Текущий реальный скор(валидационная часть): 1.3789
# Epoch 158/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4524 - val_loss: 1.5150
# Текущий реальный скор(валидационная часть): 1.3789
# Epoch 159/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4524 - val_loss: 1.5151
# Текущий реальный скор(валидационная часть): 1.347
# Скор для фолда(0) : 1.347 средний скор на префиксе = 1.347 это заняло = 91 сек.
# Фолд: 1
# Размер трейна = (3594, 77) Размер валидации = (899, 77)
# Модель: input_shape = [(None, 67), (None, 1), (None, 1), (None, 1)] output_shape = (None, 1)
# Начинаю обучение модели (GPU) количество эпох = 500
# Epoch 1/500
# 113/113 [==============================] - 1s 5ms/step - loss: 4.0769 - val_loss: 2.4940
# Текущий реальный скор(валидационная часть): 2.4339
# Epoch 2/500
# 113/113 [==============================] - 0s 4ms/step - loss: 2.0377 - val_loss: 2.0185
# Текущий реальный скор(валидационная часть): 1.9283
# Epoch 3/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.7305 - val_loss: 1.9274
# Текущий реальный скор(валидационная часть): 1.8255
# Epoch 4/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.5753 - val_loss: 1.8811
# Текущий реальный скор(валидационная часть): 1.7726
# Epoch 5/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.4821 - val_loss: 1.8449
# Текущий реальный скор(валидационная часть): 1.7279
# Epoch 6/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.4029 - val_loss: 1.7865
# Текущий реальный скор(валидационная часть): 1.6761
# Epoch 7/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.3343 - val_loss: 1.8115
# Текущий реальный скор(валидационная часть): 1.6968
# Epoch 8/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.2776 - val_loss: 1.8260
# Текущий реальный скор(валидационная часть): 1.7045
# Epoch 9/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.2228 - val_loss: 1.7917
# Текущий реальный скор(валидационная часть): 1.6773
# Epoch 10/500
# 113/113 [==============================] - 1s 5ms/step - loss: 1.1764 - val_loss: 1.7872
# Текущий реальный скор(валидационная часть): 1.6703
# Epoch 11/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.1294 - val_loss: 1.7956
# Текущий реальный скор(валидационная часть): 1.6728
# Epoch 12/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.0891 - val_loss: 1.7869
# Текущий реальный скор(валидационная часть): 1.6599
# Epoch 13/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.0512 - val_loss: 1.7552
# Текущий реальный скор(валидационная часть): 1.6382
# Epoch 14/500
# 113/113 [==============================] - 0s 4ms/step - loss: 1.0226 - val_loss: 1.7613
# Текущий реальный скор(валидационная часть): 1.6397
# Epoch 15/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.9873 - val_loss: 1.7981
# Текущий реальный скор(валидационная часть): 1.6718
# Epoch 16/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.9506 - val_loss: 1.7636
# Текущий реальный скор(валидационная часть): 1.6398
# Epoch 17/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.9251 - val_loss: 1.8545
# Текущий реальный скор(валидационная часть): 1.7224
# Epoch 18/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.9342 - val_loss: 1.6503
# Текущий реальный скор(валидационная часть): 1.5742
# Epoch 19/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.9373 - val_loss: 1.6609
# Текущий реальный скор(валидационная часть): 1.5916
# Epoch 20/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.9280 - val_loss: 1.7211
# Текущий реальный скор(валидационная часть): 1.6713
# Epoch 21/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.9368 - val_loss: 1.6712
# Текущий реальный скор(валидационная часть): 1.5998
# Epoch 22/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.9770 - val_loss: 1.6662
# Текущий реальный скор(валидационная часть): 1.5923
# Epoch 23/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.9455 - val_loss: 1.6527
# Текущий реальный скор(валидационная часть): 1.5559
# Epoch 24/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.9080 - val_loss: 1.7506
# Текущий реальный скор(валидационная часть): 1.6629
# Epoch 25/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.9330 - val_loss: 2.0854
# Текущий реальный скор(валидационная часть): 1.9186
# Epoch 26/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.8953 - val_loss: 2.1979
# Текущий реальный скор(валидационная часть): 2.008
# Epoch 27/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.8821 - val_loss: 2.2543
# Текущий реальный скор(валидационная часть): 2.0593
# Epoch 28/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.8555 - val_loss: 2.0413
# Текущий реальный скор(валидационная часть): 1.8684
# Epoch 29/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.8185 - val_loss: 1.5864
# Текущий реальный скор(валидационная часть): 1.4953
# Epoch 30/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.7618 - val_loss: 1.5766
# Текущий реальный скор(валидационная часть): 1.494
# Epoch 31/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.7250 - val_loss: 1.5714
# Текущий реальный скор(валидационная часть): 1.4788
# Epoch 32/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.6906 - val_loss: 1.5631
# Текущий реальный скор(валидационная часть): 1.4762
# Epoch 33/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.6693 - val_loss: 1.5660
# Текущий реальный скор(валидационная часть): 1.4783
# Epoch 34/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.6502 - val_loss: 1.5655
# Текущий реальный скор(валидационная часть): 1.4758
# Epoch 35/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.6354 - val_loss: 1.5642
# Текущий реальный скор(валидационная часть): 1.4752
# Epoch 36/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.6222 - val_loss: 1.5659
# Текущий реальный скор(валидационная часть): 1.4727
# Epoch 37/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.6092 - val_loss: 1.5659
# Текущий реальный скор(валидационная часть): 1.4714
# Epoch 38/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5978 - val_loss: 1.5714
# Текущий реальный скор(валидационная часть): 1.4745
# Epoch 39/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5881 - val_loss: 1.5727
# Текущий реальный скор(валидационная часть): 1.4762
# Epoch 40/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5801 - val_loss: 1.5686
# Текущий реальный скор(валидационная часть): 1.4746
# Epoch 41/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5715 - val_loss: 1.5723
# Текущий реальный скор(валидационная часть): 1.4765
# Epoch 42/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5653 - val_loss: 1.5754
# Текущий реальный скор(валидационная часть): 1.48
# Epoch 43/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.6039 - val_loss: 1.6717
# Текущий реальный скор(валидационная часть): 1.5363
# Epoch 44/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.6076 - val_loss: 1.7047
# Текущий реальный скор(валидационная часть): 1.5632
# Epoch 45/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5910 - val_loss: 1.7059
# Текущий реальный скор(валидационная часть): 1.5661
# Epoch 46/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5754 - val_loss: 1.6942
# Текущий реальный скор(валидационная часть): 1.5547
# Epoch 47/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5623 - val_loss: 1.6898
# Текущий реальный скор(валидационная часть): 1.552
# Epoch 48/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5509 - val_loss: 1.6847
# Текущий реальный скор(валидационная часть): 1.5479
# Epoch 49/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.5422 - val_loss: 1.6650
# Текущий реальный скор(валидационная часть): 1.5328
# Epoch 50/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5329 - val_loss: 1.6544
# Текущий реальный скор(валидационная часть): 1.5271
# Epoch 51/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5257 - val_loss: 1.6486
# Текущий реальный скор(валидационная часть): 1.5239
# Epoch 52/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5198 - val_loss: 1.6424
# Текущий реальный скор(валидационная часть): 1.5213
# Epoch 53/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5306 - val_loss: 1.5607
# Текущий реальный скор(валидационная часть): 1.4694
# Epoch 54/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5302 - val_loss: 1.5575
# Текущий реальный скор(валидационная часть): 1.4671
# Epoch 55/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5213 - val_loss: 1.5579
# Текущий реальный скор(валидационная часть): 1.4671
# Epoch 56/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5147 - val_loss: 1.5584
# Текущий реальный скор(валидационная часть): 1.4677
# Epoch 57/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5098 - val_loss: 1.5590
# Текущий реальный скор(валидационная часть): 1.468
# Epoch 58/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5057 - val_loss: 1.5611
# Текущий реальный скор(валидационная часть): 1.4695
# Epoch 59/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5020 - val_loss: 1.5623
# Текущий реальный скор(валидационная часть): 1.4707
# Epoch 60/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4985 - val_loss: 1.5620
# Текущий реальный скор(валидационная часть): 1.4711
# Epoch 61/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4954 - val_loss: 1.5627
# Текущий реальный скор(валидационная часть): 1.4712
# Epoch 62/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4927 - val_loss: 1.5644
# Текущий реальный скор(валидационная часть): 1.4728
# Epoch 63/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4894 - val_loss: 1.5657
# Текущий реальный скор(валидационная часть): 1.4739
# Epoch 64/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4864 - val_loss: 1.5666
# Текущий реальный скор(валидационная часть): 1.474
# Epoch 65/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4864 - val_loss: 1.6001
# Текущий реальный скор(валидационная часть): 1.497
# Epoch 66/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4823 - val_loss: 1.5990
# Текущий реальный скор(валидационная часть): 1.4964
# Epoch 67/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4795 - val_loss: 1.5992
# Текущий реальный скор(валидационная часть): 1.4967
# Epoch 68/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4774 - val_loss: 1.5993
# Текущий реальный скор(валидационная часть): 1.497
# Epoch 69/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4755 - val_loss: 1.5990
# Текущий реальный скор(валидационная часть): 1.4969
# Epoch 70/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4738 - val_loss: 1.5995
# Текущий реальный скор(валидационная часть): 1.4975
# Epoch 71/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4722 - val_loss: 1.5996
# Текущий реальный скор(валидационная часть): 1.4977
# Epoch 72/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4708 - val_loss: 1.6006
# Текущий реальный скор(валидационная часть): 1.4982
# Epoch 73/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4694 - val_loss: 1.6007
# Текущий реальный скор(валидационная часть): 1.4983
# Epoch 74/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4681 - val_loss: 1.5999
# Текущий реальный скор(валидационная часть): 1.4983
# Epoch 75/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4687 - val_loss: 1.5994
# Текущий реальный скор(валидационная часть): 1.4976
# Epoch 76/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4670 - val_loss: 1.5980
# Текущий реальный скор(валидационная часть): 1.4966
# Epoch 77/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4660 - val_loss: 1.5970
# Текущий реальный скор(валидационная часть): 1.4958
# Epoch 78/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4651 - val_loss: 1.5970
# Текущий реальный скор(валидационная часть): 1.4952
# Epoch 79/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4642 - val_loss: 1.5965
# Текущий реальный скор(валидационная часть): 1.4948
# Epoch 80/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4634 - val_loss: 1.5960
# Текущий реальный скор(валидационная часть): 1.4945
# Epoch 81/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4627 - val_loss: 1.5959
# Текущий реальный скор(валидационная часть): 1.4944
# Epoch 82/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4619 - val_loss: 1.5960
# Текущий реальный скор(валидационная часть): 1.4945
# Epoch 83/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4613 - val_loss: 1.5956
# Текущий реальный скор(валидационная часть): 1.4943
# Epoch 84/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4606 - val_loss: 1.5958
# Текущий реальный скор(валидационная часть): 1.4946
# Epoch 85/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4611 - val_loss: 1.5881
# Текущий реальный скор(валидационная часть): 1.4895
# Epoch 86/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4609 - val_loss: 1.5894
# Текущий реальный скор(валидационная часть): 1.49
# Epoch 87/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4604 - val_loss: 1.5897
# Текущий реальный скор(валидационная часть): 1.4902
# Epoch 88/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4600 - val_loss: 1.5900
# Текущий реальный скор(валидационная часть): 1.4905
# Epoch 89/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4595 - val_loss: 1.5905
# Текущий реальный скор(валидационная часть): 1.4909
# Epoch 90/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4591 - val_loss: 1.5910
# Текущий реальный скор(валидационная часть): 1.4912
# Epoch 91/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4588 - val_loss: 1.5913
# Текущий реальный скор(валидационная часть): 1.4915
# Epoch 92/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4584 - val_loss: 1.5916
# Текущий реальный скор(валидационная часть): 1.4918
# Epoch 93/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4580 - val_loss: 1.5921
# Текущий реальный скор(валидационная часть): 1.4922
# Epoch 94/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4576 - val_loss: 1.5917
# Текущий реальный скор(валидационная часть): 1.4924
# Epoch 95/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4583 - val_loss: 1.6068
# Текущий реальный скор(валидационная часть): 1.5022
# Epoch 96/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4573 - val_loss: 1.6071
# Текущий реальный скор(валидационная часть): 1.5025
# Epoch 97/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4569 - val_loss: 1.6075
# Текущий реальный скор(валидационная часть): 1.503
# Epoch 98/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4566 - val_loss: 1.6078
# Текущий реальный скор(валидационная часть): 1.5033
# Epoch 99/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4564 - val_loss: 1.6080
# Текущий реальный скор(валидационная часть): 1.5035
# Epoch 100/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4561 - val_loss: 1.6081
# Текущий реальный скор(валидационная часть): 1.5037
# Epoch 101/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4558 - val_loss: 1.6082
# Текущий реальный скор(валидационная часть): 1.5038
# Epoch 102/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4555 - val_loss: 1.6085
# Текущий реальный скор(валидационная часть): 1.5041
# Epoch 103/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4553 - val_loss: 1.6087
# Текущий реальный скор(валидационная часть): 1.5043
# Epoch 104/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4551 - val_loss: 1.6089
# Текущий реальный скор(валидационная часть): 1.5045
# Epoch 105/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.4547 - val_loss: 1.6164
# Текущий реальный скор(валидационная часть): 1.5102
# Epoch 106/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4541 - val_loss: 1.6174
# Текущий реальный скор(валидационная часть): 1.5109
# Epoch 107/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4540 - val_loss: 1.6176
# Текущий реальный скор(валидационная часть): 1.5111
# Epoch 108/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.4538 - val_loss: 1.6176
# Текущий реальный скор(валидационная часть): 1.5112
# Epoch 109/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4537 - val_loss: 1.6177
# Текущий реальный скор(валидационная часть): 1.5113
# Epoch 110/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.4536 - val_loss: 1.6178
# Текущий реальный скор(валидационная часть): 1.5113
# Epoch 111/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4535 - val_loss: 1.6185
# Текущий реальный скор(валидационная часть): 1.5114
# Epoch 112/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4534 - val_loss: 1.6186
# Текущий реальный скор(валидационная часть): 1.5115
# Epoch 113/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4533 - val_loss: 1.6186
# Текущий реальный скор(валидационная часть): 1.5116
# Epoch 114/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4532 - val_loss: 1.6193
# Текущий реальный скор(валидационная часть): 1.5116
# Epoch 115/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4527 - val_loss: 1.6210
# Текущий реальный скор(валидационная часть): 1.5129
# Epoch 116/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4525 - val_loss: 1.6210
# Текущий реальный скор(валидационная часть): 1.5133
# Epoch 117/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4524 - val_loss: 1.6212
# Текущий реальный скор(валидационная часть): 1.5135
# Epoch 118/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4524 - val_loss: 1.6213
# Текущий реальный скор(валидационная часть): 1.5136
# Epoch 119/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4523 - val_loss: 1.6213
# Текущий реальный скор(валидационная часть): 1.5137
# Epoch 120/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4523 - val_loss: 1.6214
# Текущий реальный скор(валидационная часть): 1.5137
# Epoch 121/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.4522 - val_loss: 1.6214
# Текущий реальный скор(валидационная часть): 1.5138
# Epoch 122/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4522 - val_loss: 1.6214
# Текущий реальный скор(валидационная часть): 1.5138
# Epoch 123/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4521 - val_loss: 1.6215
# Текущий реальный скор(валидационная часть): 1.5139
# Epoch 124/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4520 - val_loss: 1.6215
# Текущий реальный скор(валидационная часть): 1.5139
# Epoch 125/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4518 - val_loss: 1.6220
# Текущий реальный скор(валидационная часть): 1.5143
# Epoch 126/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.4517 - val_loss: 1.6223
# Текущий реальный скор(валидационная часть): 1.5145
# Epoch 127/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4517 - val_loss: 1.6224
# Текущий реальный скор(валидационная часть): 1.5146
# Epoch 128/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4516 - val_loss: 1.6226
# Текущий реальный скор(валидационная часть): 1.5147
# Epoch 129/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4516 - val_loss: 1.6226
# Текущий реальный скор(валидационная часть): 1.5148
# Epoch 130/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4516 - val_loss: 1.6227
# Текущий реальный скор(валидационная часть): 1.5148
# Epoch 131/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4516 - val_loss: 1.6227
# Текущий реальный скор(валидационная часть): 1.5149
# Epoch 132/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4515 - val_loss: 1.6227
# Текущий реальный скор(валидационная часть): 1.5149
# Epoch 133/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4515 - val_loss: 1.6227
# Текущий реальный скор(валидационная часть): 1.5149
# Epoch 134/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4515 - val_loss: 1.6227
# Текущий реальный скор(валидационная часть): 1.5149
# Epoch 135/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4513 - val_loss: 1.6229
# Текущий реальный скор(валидационная часть): 1.515
# Epoch 136/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4513 - val_loss: 1.6230
# Текущий реальный скор(валидационная часть): 1.5151
# Epoch 137/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4513 - val_loss: 1.6230
# Текущий реальный скор(валидационная часть): 1.5151
# Epoch 138/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4513 - val_loss: 1.6231
# Текущий реальный скор(валидационная часть): 1.5152
# Epoch 139/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4513 - val_loss: 1.6231
# Текущий реальный скор(валидационная часть): 1.5152
# Epoch 140/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4513 - val_loss: 1.6232
# Текущий реальный скор(валидационная часть): 1.5153
# Epoch 141/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4512 - val_loss: 1.6232
# Текущий реальный скор(валидационная часть): 1.5153
# Epoch 142/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.4512 - val_loss: 1.6232
# Текущий реальный скор(валидационная часть): 1.5153
# Epoch 143/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4512 - val_loss: 1.6232
# Текущий реальный скор(валидационная часть): 1.5153
# Epoch 144/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4512 - val_loss: 1.6232
# Текущий реальный скор(валидационная часть): 1.5153
# Epoch 145/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4511 - val_loss: 1.6233
# Текущий реальный скор(валидационная часть): 1.5154
# Epoch 146/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4511 - val_loss: 1.6233
# Текущий реальный скор(валидационная часть): 1.5154
# Epoch 147/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4511 - val_loss: 1.6234
# Текущий реальный скор(валидационная часть): 1.5154
# Epoch 148/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4511 - val_loss: 1.6234
# Текущий реальный скор(валидационная часть): 1.5154
# Epoch 149/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4511 - val_loss: 1.6234
# Текущий реальный скор(валидационная часть): 1.5155
# Epoch 150/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4511 - val_loss: 1.6234
# Текущий реальный скор(валидационная часть): 1.5155
# Epoch 151/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4511 - val_loss: 1.6234
# Текущий реальный скор(валидационная часть): 1.5155
# ...
# Текущий реальный скор(валидационная часть): 1.4562
# Epoch 26/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.8544 - val_loss: 1.7295
# Текущий реальный скор(валидационная часть): 1.5863
# Epoch 27/500
# 113/113 [==============================] - 1s 6ms/step - loss: 0.8262 - val_loss: 1.5677
# Текущий реальный скор(валидационная часть): 1.5036
# Epoch 28/500
# 113/113 [==============================] - 1s 6ms/step - loss: 0.8728 - val_loss: 1.5105
# Текущий реальный скор(валидационная часть): 1.4271
# Epoch 29/500
# 113/113 [==============================] - 1s 6ms/step - loss: 0.7706 - val_loss: 1.5449
# Текущий реальный скор(валидационная часть): 1.4439
# Epoch 30/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.7338 - val_loss: 1.5285
# Текущий реальный скор(валидационная часть): 1.4479
# Epoch 31/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.6998 - val_loss: 1.5337
# Текущий реальный скор(валидационная часть): 1.4479
# Epoch 32/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.6861 - val_loss: 1.5587
# Текущий реальный скор(валидационная часть): 1.4506
# Epoch 33/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.6985 - val_loss: 1.5344
# Текущий реальный скор(валидационная часть): 1.4354
# Epoch 34/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.7426 - val_loss: 1.6212
# Текущий реальный скор(валидационная часть): 1.5777
# Epoch 35/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.7208 - val_loss: 1.6647
# Текущий реальный скор(валидационная часть): 1.6484
# Epoch 36/500
# 113/113 [==============================] - 1s 6ms/step - loss: 0.6978 - val_loss: 1.6716
# Текущий реальный скор(валидационная часть): 1.6496
# Epoch 37/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.7006 - val_loss: 1.6352
# Текущий реальный скор(валидационная часть): 1.6073
# Epoch 38/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.7203 - val_loss: 1.5335
# Текущий реальный скор(валидационная часть): 1.4734
# Epoch 39/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.7329 - val_loss: 1.5869
# Текущий реальный скор(валидационная часть): 1.4527
# Epoch 40/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.6643 - val_loss: 1.6450
# Текущий реальный скор(валидационная часть): 1.4954
# Epoch 41/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.6300 - val_loss: 1.6021
# Текущий реальный скор(валидационная часть): 1.4579
# Epoch 42/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.6056 - val_loss: 1.5784
# Текущий реальный скор(валидационная часть): 1.4419
# Epoch 43/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.5897 - val_loss: 1.5669
# Текущий реальный скор(валидационная часть): 1.4363
# Epoch 44/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5775 - val_loss: 1.5736
# Текущий реальный скор(валидационная часть): 1.4421
# Epoch 45/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5670 - val_loss: 1.5716
# Текущий реальный скор(валидационная часть): 1.4403
# Epoch 46/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5586 - val_loss: 1.5723
# Текущий реальный скор(валидационная часть): 1.4413
# Epoch 47/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5520 - val_loss: 1.5726
# Текущий реальный скор(валидационная часть): 1.4419
# Epoch 48/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5481 - val_loss: 1.5756
# Текущий реальный скор(валидационная часть): 1.4448
# Epoch 49/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5907 - val_loss: 1.5623
# Текущий реальный скор(валидационная часть): 1.5193
# Epoch 50/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5655 - val_loss: 1.5564
# Текущий реальный скор(валидационная часть): 1.5079
# Epoch 51/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5365 - val_loss: 1.5509
# Текущий реальный скор(валидационная часть): 1.4961
# Epoch 52/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5167 - val_loss: 1.5483
# Текущий реальный скор(валидационная часть): 1.4924
# Epoch 53/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5032 - val_loss: 1.5469
# Текущий реальный скор(валидационная часть): 1.4893
# Epoch 54/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4928 - val_loss: 1.5465
# Текущий реальный скор(валидационная часть): 1.4882
# Epoch 55/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4843 - val_loss: 1.5463
# Текущий реальный скор(валидационная часть): 1.4877
# Epoch 56/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4767 - val_loss: 1.5485
# Текущий реальный скор(валидационная часть): 1.4887
# Epoch 57/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.4707 - val_loss: 1.5495
# Текущий реальный скор(валидационная часть): 1.4887
# Epoch 58/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4654 - val_loss: 1.5504
# Текущий реальный скор(валидационная часть): 1.4887
# Epoch 59/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4817 - val_loss: 1.5400
# Текущий реальный скор(валидационная часть): 1.4659
# Epoch 60/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4780 - val_loss: 1.5408
# Текущий реальный скор(валидационная часть): 1.4605
# Epoch 61/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4717 - val_loss: 1.5412
# Текущий реальный скор(валидационная часть): 1.4574
# Epoch 62/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4668 - val_loss: 1.5445
# Текущий реальный скор(валидационная часть): 1.4566
# Epoch 63/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4623 - val_loss: 1.5451
# Текущий реальный скор(валидационная часть): 1.4551
# Epoch 64/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4583 - val_loss: 1.5459
# Текущий реальный скор(валидационная часть): 1.4546
# Epoch 65/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4548 - val_loss: 1.5465
# Текущий реальный скор(валидационная часть): 1.4537
# Epoch 66/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4514 - val_loss: 1.5475
# Текущий реальный скор(валидационная часть): 1.4541
# Epoch 67/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4481 - val_loss: 1.5481
# Текущий реальный скор(валидационная часть): 1.4538
# Epoch 68/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4454 - val_loss: 1.5492
# Текущий реальный скор(валидационная часть): 1.4538
# Epoch 69/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4533 - val_loss: 1.5751
# Текущий реальный скор(валидационная часть): 1.4607
# Epoch 70/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4533 - val_loss: 1.5711
# Текущий реальный скор(валидационная часть): 1.4577
# Epoch 71/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4498 - val_loss: 1.5688
# Текущий реальный скор(валидационная часть): 1.456
# Epoch 72/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4468 - val_loss: 1.5667
# Текущий реальный скор(валидационная часть): 1.4549
# Epoch 73/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4441 - val_loss: 1.5658
# Текущий реальный скор(валидационная часть): 1.4549
# Epoch 74/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4417 - val_loss: 1.5653
# Текущий реальный скор(валидационная часть): 1.4552
# Epoch 75/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4396 - val_loss: 1.5646
# Текущий реальный скор(валидационная часть): 1.4554
# Epoch 76/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4375 - val_loss: 1.5645
# Текущий реальный скор(валидационная часть): 1.4559
# Epoch 77/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4357 - val_loss: 1.5642
# Текущий реальный скор(валидационная часть): 1.4561
# Epoch 78/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4338 - val_loss: 1.5645
# Текущий реальный скор(валидационная часть): 1.457
# Epoch 79/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4388 - val_loss: 1.5481
# Текущий реальный скор(валидационная часть): 1.4606
# Epoch 80/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4350 - val_loss: 1.5481
# Текущий реальный скор(валидационная часть): 1.4613
# Epoch 81/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4333 - val_loss: 1.5481
# Текущий реальный скор(валидационная часть): 1.4619
# Epoch 82/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4319 - val_loss: 1.5481
# Текущий реальный скор(валидационная часть): 1.4624
# Epoch 83/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4306 - val_loss: 1.5483
# Текущий реальный скор(валидационная часть): 1.4629
# Epoch 84/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4294 - val_loss: 1.5484
# Текущий реальный скор(валидационная часть): 1.4634
# Epoch 85/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4283 - val_loss: 1.5486
# Текущий реальный скор(валидационная часть): 1.4638
# Epoch 86/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4272 - val_loss: 1.5489
# Текущий реальный скор(валидационная часть): 1.4643
# Epoch 87/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4262 - val_loss: 1.5492
# Текущий реальный скор(валидационная часть): 1.4648
# Epoch 88/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4253 - val_loss: 1.5494
# Текущий реальный скор(валидационная часть): 1.4652
# Epoch 89/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4255 - val_loss: 1.5462
# Текущий реальный скор(валидационная часть): 1.4687
# Epoch 90/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4260 - val_loss: 1.5458
# Текущий реальный скор(валидационная часть): 1.4683
# Epoch 91/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4253 - val_loss: 1.5458
# Текущий реальный скор(валидационная часть): 1.4683
# Epoch 92/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4247 - val_loss: 1.5457
# Текущий реальный скор(валидационная часть): 1.4683
# Epoch 93/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4241 - val_loss: 1.5457
# Текущий реальный скор(валидационная часть): 1.4683
# Epoch 94/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4236 - val_loss: 1.5458
# Текущий реальный скор(валидационная часть): 1.4684
# Epoch 95/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4230 - val_loss: 1.5459
# Текущий реальный скор(валидационная часть): 1.4685
# Epoch 96/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4225 - val_loss: 1.5460
# Текущий реальный скор(валидационная часть): 1.4687
# Epoch 97/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4220 - val_loss: 1.5461
# Текущий реальный скор(валидационная часть): 1.4687
# Epoch 98/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4215 - val_loss: 1.5462
# Текущий реальный скор(валидационная часть): 1.4689
# Epoch 99/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4218 - val_loss: 1.5477
# Текущий реальный скор(валидационная часть): 1.4663
# Epoch 100/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4204 - val_loss: 1.5477
# Текущий реальный скор(валидационная часть): 1.4663
# Epoch 101/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4201 - val_loss: 1.5477
# Текущий реальный скор(валидационная часть): 1.4663
# Epoch 102/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4198 - val_loss: 1.5477
# Текущий реальный скор(валидационная часть): 1.4663
# Epoch 103/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4195 - val_loss: 1.5477
# Текущий реальный скор(валидационная часть): 1.4663
# Epoch 104/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4192 - val_loss: 1.5477
# Текущий реальный скор(валидационная часть): 1.4663
# Epoch 105/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4190 - val_loss: 1.5477
# Текущий реальный скор(валидационная часть): 1.4664
# Epoch 106/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4187 - val_loss: 1.5477
# Текущий реальный скор(валидационная часть): 1.4664
# Epoch 107/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4185 - val_loss: 1.5477
# Текущий реальный скор(валидационная часть): 1.4664
# Epoch 108/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4182 - val_loss: 1.5478
# Текущий реальный скор(валидационная часть): 1.4666
# Epoch 109/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4174 - val_loss: 1.5499
# Текущий реальный скор(валидационная часть): 1.4657
# Epoch 110/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4167 - val_loss: 1.5501
# Текущий реальный скор(валидационная часть): 1.4656
# Epoch 111/500
# 113/113 [==============================] - 1s 6ms/step - loss: 0.4165 - val_loss: 1.5501
# Текущий реальный скор(валидационная часть): 1.4655
# Epoch 112/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4164 - val_loss: 1.5501
# Текущий реальный скор(валидационная часть): 1.4656
# Epoch 113/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4162 - val_loss: 1.5501
# Текущий реальный скор(валидационная часть): 1.4656
# Epoch 114/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4161 - val_loss: 1.5501
# Текущий реальный скор(валидационная часть): 1.4656
# Epoch 115/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4160 - val_loss: 1.5501
# Текущий реальный скор(валидационная часть): 1.4656
# Epoch 116/500
# 113/113 [==============================] - 1s 4ms/step - loss: 0.4159 - val_loss: 1.5501
# Текущий реальный скор(валидационная часть): 1.4656
# Epoch 117/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4158 - val_loss: 1.5501
# Текущий реальный скор(валидационная часть): 1.4657
# Epoch 118/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4157 - val_loss: 1.5501
# Текущий реальный скор(валидационная часть): 1.4657
# Epoch 119/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4150 - val_loss: 1.5507
# Текущий реальный скор(валидационная часть): 1.4655
# Epoch 120/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4148 - val_loss: 1.5509
# Текущий реальный скор(валидационная часть): 1.4655
# Epoch 121/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4146 - val_loss: 1.5510
# Текущий реальный скор(валидационная часть): 1.4655
# Epoch 122/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4146 - val_loss: 1.5511
# Текущий реальный скор(валидационная часть): 1.4655
# Epoch 123/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4145 - val_loss: 1.5511
# Текущий реальный скор(валидационная часть): 1.4655
# Epoch 124/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4145 - val_loss: 1.5511
# Текущий реальный скор(валидационная часть): 1.4655
# Epoch 125/500
# 113/113 [==============================] - 1s 6ms/step - loss: 0.4144 - val_loss: 1.5511
# Текущий реальный скор(валидационная часть): 1.4655
# Epoch 126/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4143 - val_loss: 1.5511
# Текущий реальный скор(валидационная часть): 1.4655
# Epoch 127/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4143 - val_loss: 1.5511
# Текущий реальный скор(валидационная часть): 1.4655
# Epoch 128/500
# 113/113 [==============================] - 1s 5ms/step - loss: 0.4142 - val_loss: 1.5511
# Текущий реальный скор(валидационная часть): 1.4271
# Скор для фолда(4) : 1.4271 средний скор на префиксе = 1.4365 это заняло = 85 сек.
# Процесс обучения модели занял = 448 секунд

# %%
#Предикт нейронной сетью на test
def get_nn_predict(models, test):
  result = np.zeros(len(test))  
  test_ds = get_dataset(
      test[NUM_FEATURES_COLUMNS].values, 
      np.zeros(len(test)), 
      test[['region']].values, 
      test[['city']].values, 
      test[['realty_type']].values, 
      len(test))
  for model in models:
    predict = model.predict(test_ds)[:,0]    
    result += (predict / MUL_TARGET) / len(models)
  return result

test_nn_predict = get_nn_predict(models_nn, test)
# Out:
# WARNING:tensorflow:5 out of the last 133 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd3abd144d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 134 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd3abb125f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#LightGBM кастомная метрика
def feval_deviation(y_pred, lgb_train):
    y_true = lgb_train.get_label()
    return 'deviation_error', deviation_metric(y_true, y_pred), False

#Функция для обучения модели LightGBM
def train_lgb(train, valid, num_features, categorical_features, target_train, target_valid, EPOCHS, params):                
    #feature_importances = np.zeros(len(features))                
    train_dataset = lgb.Dataset(train[num_features + categorical_features], target_train, weight = (1.0 / target_train), categorical_feature = categorical_features)
    valid_dataset = lgb.Dataset(valid[num_features + categorical_features], target_valid, weight = (1.0 / target_valid), categorical_feature = categorical_features)
    model = lgb.train(
        params = params, 
        num_boost_round = EPOCHS,
        train_set = train_dataset, 
        valid_sets = [train_dataset, valid_dataset], 
        verbose_eval = 100,
        early_stopping_rounds = int(5 / params['learning_rate']),                          
        feval = feval_deviation)
        
    y_valid = model.predict(valid[num_features + categorical_features])
    #feature_importances = model.feature_importance(importance_type='gain') / 5.0            
    #lgb.plot_importance(model,max_num_features = 41)        
    
    return model, y_valid

# %%
start_train_model_time = time.time()

boosting_seed = 41
boosting_params = {
    'bagging_fraction': 0.9, 
    'bagging_freq': 1, 
    'boost': 'gbdt', 
    'feature_fraction': 0.9, 
    'max_depth':3,
    'learning_rate': 0.05, 
    'metric': 'custom', 
    'objective': 'regression_l1', 
    'verbose': -1,
    'n_jobs': -1,
    'seed':boosting_seed,
    'feature_fraction_seed': boosting_seed,
    'bagging_seed': boosting_seed,
    'drop_seed': boosting_seed,
    'data_random_seed': boosting_seed,
}

#Количество эпох обучения
EPOCHS = 10000
scores = []
lgb_predicts = np.zeros(len(train))

lgb_models = []
for fold_num, (train_indexes, valid_indexes) in enumerate(split_list):  
  start_time = time.time()
  print(f"Фолд: {fold_num}")

  train_sub_df = train[features_columns_order].loc[train_indexes].reset_index(drop=True)    
  valid_sub_df = train[features_columns_order].loc[valid_indexes].reset_index(drop=True)    

  print(f"Размер трейна = {train_sub_df.shape} Размер валидации = {valid_sub_df.shape}")  
  #Обучаем LightGBM и делаем предикт на валидационной выборке  
  model, predict_validation = train_lgb(
      train_sub_df,
      valid_sub_df,      
      NUM_FEATURES_COLUMNS,
      CATEGORICAL_FEATURES_COLUMNS,
      train_sub_df[TARGET_COLUMNS[0]].values,
      valid_sub_df[TARGET_COLUMNS[0]].values,      
      EPOCHS,
      boosting_params)    

  lgb_models += [model]
  predict_on_validation = model.predict(valid_sub_df[NUM_FEATURES_COLUMNS + CATEGORICAL_FEATURES_COLUMNS])
  lgb_predicts[valid_indexes] = predict_on_validation
  targets_for_validation = valid_sub_df[TARGET_COLUMNS].values[:,0]
  current_score = deviation_metric(targets_for_validation, predict_on_validation)
  scores += [current_score]
  print(f"Скор для фолда({fold_num}) : {np.round(current_score, 4)} средний скор на префиксе = {np.round(np.mean(scores), 4)} это заняло = {int(time.time() - start_time)} сек.")
print(f"Процесс обучения модели занял = {int(time.time() - start_train_model_time)} секунд")
# Out:
# Фолд: 0
# Размер трейна = (3594, 77) Размер валидации = (899, 77)
# Training until validation scores don't improve for 100 rounds.
# [100]	training's deviation_error: 1.53568	valid_1's deviation_error: 1.64119
# [200]	training's deviation_error: 1.45241	valid_1's deviation_error: 1.62259
# Early stopping, best iteration is:
# [192]	training's deviation_error: 1.42565	valid_1's deviation_error: 1.58487
# Скор для фолда(0) : 1.5849 средний скор на префиксе = 1.5849 это заняло = 8 сек.
# Фолд: 1
# Размер трейна = (3594, 77) Размер валидации = (899, 77)
# Training until validation scores don't improve for 100 rounds.
# [100]	training's deviation_error: 1.53715	valid_1's deviation_error: 1.84674
# [200]	training's deviation_error: 1.83705	valid_1's deviation_error: 2.17574
# Early stopping, best iteration is:
# [132]	training's deviation_error: 1.51262	valid_1's deviation_error: 1.83614
# Скор для фолда(1) : 1.8361 средний скор на префиксе = 1.7105 это заняло = 6 сек.
# Фолд: 2
# Размер трейна = (3594, 77) Размер валидации = (899, 77)
# Training until validation scores don't improve for 100 rounds.
# [100]	training's deviation_error: 1.57927	valid_1's deviation_error: 1.68543
# [200]	training's deviation_error: 1.42658	valid_1's deviation_error: 1.58932
# [300]	training's deviation_error: 1.33472	valid_1's deviation_error: 1.55587
# [400]	training's deviation_error: 1.27717	valid_1's deviation_error: 1.53133
# [500]	training's deviation_error: 1.22604	valid_1's deviation_error: 1.51845
# [600]	training's deviation_error: 1.20201	valid_1's deviation_error: 1.51269
# [700]	training's deviation_error: 1.18345	valid_1's deviation_error: 1.50722
# [800]	training's deviation_error: 1.16482	valid_1's deviation_error: 1.50297
# [900]	training's deviation_error: 1.15094	valid_1's deviation_error: 1.49405
# [1000]	training's deviation_error: 1.13475	valid_1's deviation_error: 1.49021
# [1100]	training's deviation_error: 1.12402	valid_1's deviation_error: 1.48713
# [1200]	training's deviation_error: 1.11017	valid_1's deviation_error: 1.48047
# [1300]	training's deviation_error: 1.09888	valid_1's deviation_error: 1.47804
# [1400]	training's deviation_error: 1.08833	valid_1's deviation_error: 1.47832
# Early stopping, best iteration is:
# [1306]	training's deviation_error: 1.0978	valid_1's deviation_error: 1.47736
# Скор для фолда(2) : 1.4774 средний скор на префиксе = 1.6328 это заняло = 39 сек.
# Фолд: 3
# Размер трейна = (3595, 77) Размер валидации = (898, 77)
# Training until validation scores don't improve for 100 rounds.
# [100]	training's deviation_error: 1.55359	valid_1's deviation_error: 1.68291
# [200]	training's deviation_error: 1.75929	valid_1's deviation_error: 1.94584
# Early stopping, best iteration is:
# [119]	training's deviation_error: 1.53296	valid_1's deviation_error: 1.66659
# Скор для фолда(3) : 1.6666 средний скор на префиксе = 1.6412 это заняло = 6 сек.
# Фолд: 4
# Размер трейна = (3595, 77) Размер валидации = (898, 77)
# Training until validation scores don't improve for 100 rounds.
# [100]	training's deviation_error: 1.57733	valid_1's deviation_error: 1.80485
# [200]	training's deviation_error: 1.52826	valid_1's deviation_error: 1.77164
# Early stopping, best iteration is:
# [179]	training's deviation_error: 1.50144	valid_1's deviation_error: 1.74318
# Скор для фолда(4) : 1.7432 средний скор на префиксе = 1.6616 это заняло = 8 сек.
# Процесс обучения модели занял = 68 секунд

# %%
#Предикт lgb на test
def get_lgb_predict(models, test):
  result = np.zeros(len(test))    
  for model in models:
    predict = model.predict(test[NUM_FEATURES_COLUMNS + CATEGORICAL_FEATURES_COLUMNS]) 
    result += predict / len(models)
  return result

test_lgb_predict = get_lgb_predict(lgb_models, test)

# %%
test_lgb_predict.min(), test_lgb_predict.max(), test_lgb_predict.mean()
# Out:
# (13358.023046745368, 149254.61665611007, 50046.98270233456)

# %%
#Кастомная метрика для xgboost
def xbg_error(preds, dtrain):
    labels = dtrain.get_label()
    err = deviation_metric(labels, preds)
    return 'deviation_error', err

def train_xgb(train, valid, num_features, categorical_features, target_train, target_valid, EPOCHS, params):        

    dtest = xgb.DMatrix(test[num_features + categorical_features])
    y_valid = np.zeros(len(valid))    
    
    dtrain = xgb.DMatrix(train[num_features + categorical_features], target_train, weight = 1.0 / target_train)
    dvalid = xgb.DMatrix(valid[num_features + categorical_features], target_valid, weight = 1.0 / target_valid)
    model = xgb.train(
        params,
        dtrain,
        EPOCHS,        
        [(dvalid, "valid")],
        verbose_eval=250,
        early_stopping_rounds=500,
        feval=xbg_error,
    )
    y_valid = model.predict(dvalid)    
            
    return model, y_valid

# %%
start_train_model_time = time.time()

xgboost_seed = 41
xgboost_params = {
        "subsample": 0.60,
        "colsample_bytree": 0.40,
        "max_depth": 7,
        "learning_rate": 0.01,
        "objective": "reg:squarederror",
        'disable_default_eval_metric': 1, 
        "nthread": -1,                
        "max_bin": 64, 
        'min_child_weight': 0.0,
        'reg_lambda': 0.0,
        'reg_alpha': 0.0, 
        'seed' : xgboost_seed,
    }

#Количество эпох обучения
EPOCHS = 10000
scores = []
xgb_predicts = np.zeros(len(train))

xgb_models = []
for fold_num, (train_indexes, valid_indexes) in enumerate(split_list):  
  start_time = time.time()
  print(f"Фолд: {fold_num}")

  train_sub_df = train[features_columns_order].loc[train_indexes].reset_index(drop=True)    
  valid_sub_df = train[features_columns_order].loc[valid_indexes].reset_index(drop=True)    

  print(f"Размер трейна = {train_sub_df.shape} Размер валидации = {valid_sub_df.shape}")  
  #Обучаем Xgboost и делаем предикт на валидационной выборке  
  model, predict_validation = train_xgb(
      train_sub_df,
      valid_sub_df,      
      NUM_FEATURES_COLUMNS,
      CATEGORICAL_FEATURES_COLUMNS,
      train_sub_df[TARGET_COLUMNS[0]].values,
      valid_sub_df[TARGET_COLUMNS[0]].values,      
      EPOCHS,
      xgboost_params)    
  
  xgb_models += [model]
  predict_on_validation = model.predict(xgb.DMatrix(valid_sub_df[NUM_FEATURES_COLUMNS + CATEGORICAL_FEATURES_COLUMNS]))
  xgb_predicts[valid_indexes] = predict_on_validation
  targets_for_validation = valid_sub_df[TARGET_COLUMNS].values[:,0]
  current_score = deviation_metric(targets_for_validation, predict_on_validation)
  scores += [current_score]
  print(f"Скор для фолда({fold_num}) : {np.round(current_score, 4)} средний скор на префиксе = {np.round(np.mean(scores), 4)} это заняло = {int(time.time() - start_time)} сек.")
print(f"Процесс обучения модели занял = {int(time.time() - start_train_model_time)} секунд")
# Out:
# Фолд: 0
# Размер трейна = (3594, 77) Размер валидации = (899, 77)
# [0]	valid-deviation_error:9.9
# Will train until valid-deviation_error hasn't improved in 500 rounds.
# [250]	valid-deviation_error:1.36995
# [500]	valid-deviation_error:1.40984
# Stopping. Best iteration:
# [223]	valid-deviation_error:1.32348
#
# Скор для фолда(0) : 1.4052 средний скор на префиксе = 1.4052 это заняло = 12 сек.
# Фолд: 1
# Размер трейна = (3594, 77) Размер валидации = (899, 77)
# [0]	valid-deviation_error:9.9
# Will train until valid-deviation_error hasn't improved in 500 rounds.
# [250]	valid-deviation_error:1.52722
# [500]	valid-deviation_error:1.60812
# Stopping. Best iteration:
# [240]	valid-deviation_error:1.51704
#
# Скор для фолда(1) : 1.5937 средний скор на префиксе = 1.4994 это заняло = 12 сек.
# Фолд: 2
# Размер трейна = (3594, 77) Размер валидации = (899, 77)
# [0]	valid-deviation_error:9.9
# Will train until valid-deviation_error hasn't improved in 500 rounds.
# [250]	valid-deviation_error:1.35104
# [500]	valid-deviation_error:1.41847
# [750]	valid-deviation_error:1.47197
# Stopping. Best iteration:
# [255]	valid-deviation_error:1.34806
#
# Скор для фолда(2) : 1.4733 средний скор на префиксе = 1.4907 это заняло = 12 сек.
# Фолд: 3
# Размер трейна = (3595, 77) Размер валидации = (898, 77)
# [0]	valid-deviation_error:9.9
# Will train until valid-deviation_error hasn't improved in 500 rounds.
# [250]	valid-deviation_error:1.48995
# [500]	valid-deviation_error:1.5172
# [750]	valid-deviation_error:1.49584
# Stopping. Best iteration:
# [312]	valid-deviation_error:1.47319
#
# Скор для фолда(3) : 1.4968 средний скор на префиксе = 1.4923 это заняло = 13 сек.
# Фолд: 4
# Размер трейна = (3595, 77) Размер валидации = (898, 77)
# [0]	valid-deviation_error:9.9
# Will train until valid-deviation_error hasn't improved in 500 rounds.
# [250]	valid-deviation_error:1.57998
# [500]	valid-deviation_error:1.49632
# [750]	valid-deviation_error:1.50838
# Stopping. Best iteration:
# [470]	valid-deviation_error:1.48868
#
# Скор для фолда(4) : 1.4909 средний скор на префиксе = 1.492 это заняло = 16 сек.
# Процесс обучения модели занял = 67 секунд

# %%
#Предикт xgb на test
def get_xgb_predict(models, test):
  result = np.zeros(len(test))    
  for model in models:
    predict = model.predict(xgb.DMatrix(test[NUM_FEATURES_COLUMNS + CATEGORICAL_FEATURES_COLUMNS]))
    result += predict / len(models)
  return result

test_xgb_predict = get_xgb_predict(xgb_models, test)

# %%
test_xgb_predict.min(), test_xgb_predict.max(), test_xgb_predict.mean()
# Out:
# (11245.448272705078, 1177149.71875, 64235.81543774274)

# %%
train_targets = train[TARGET_COLUMNS[0]].values

def minimize_arit(W):
    ypred = W[0] * nn_predicts + W[1] * lgb_predicts + W[2] * xgb_predicts
    return deviation_metric(train_targets, ypred)

W = minimize(minimize_arit, [1.0 / 3] * 3, options={'gtol': 1e-6, 'disp': True}).x
print('Weights arit:', W)
# Out:
# Optimization terminated successfully.
#          Current function value: 1.282784
#          Iterations: 15
#          Function evaluations: 95
#          Gradient evaluations: 19
# Weights arit: [0.41767686 0.08052237 0.44846108]

# %%
print(nn_predicts.min(), nn_predicts.max(), nn_predicts.mean())
print(lgb_predicts.min(), lgb_predicts.max(), lgb_predicts.mean())
print(xgb_predicts.min(), xgb_predicts.max(), xgb_predicts.mean())
# Out:
# 0.0 308148.34375 56782.2756794858
# 9307.5935162837 159284.05132592737 51148.60444212896
# 16983.75 1306497.25 66448.84113786375

# %%
test_submission = pd.read_csv('test_submission.csv')
test_submission['per_square_meter_price'] = test_nn_predict * W[0] + test_lgb_predict * W[1] + test_xgb_predict * W[2]
test_submission['per_square_meter_price'] = test_submission['per_square_meter_price'].apply(lambda x: max(0.0, x))
test_submission.to_csv('submission.csv', index = False)
test_submission.head(5)
# Out:
#            id  per_square_meter_price
# 0  COL_289284            38885.217138
# 1  COL_289305            43487.668814
# 2  COL_289318            40714.676957
# 3  COL_289354            81841.632358
# 4  COL_289399            48660.340424
